# %%
import pandas as pd
import numpy as np

# %%
from ultralytics import YOLO
# Out:
# WARNING:tensorflow:From C:\Users\ACER\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
path=r'D:\identity_Whoami\alchemy\problems (1)\problems\frag0.csv'

# %%
def read_csv ( csv_path ):
    np_path_XYs = np . genfromtxt ( csv_path , delimiter =',')
    path_XYs = []
    for i in np . unique ( np_path_XYs [: , 0]):
        npXYs = np_path_XYs [ np_path_XYs [: , 0] == i ][: , 1:]
        XYs = []
        for j in np . unique ( npXYs [: , 0]):
            XY = npXYs [ npXYs [: , 0] == j ][: , 1:]
            XYs.append(XY)
        path_XYs . append ( XYs )
    return path_XYs

# %%
firstimg=read_csv(path)

# %%
plt.plot(firstimg[0][0][:,0],firstimg[0][0][:,1])

# %%
from matplotlib import pyplot as plt
polylines=[x for x in firstimg]
count=0
from PIL import Image
fig=plt.figure(figsize=(10, 6))
for i in polylines:
    plt.plot(i[0][:,0],i[0][:,1])
    count+=1
print(count)
# Out:
# 10

# %%
import numpy as np

def compute_properties(polyline):
    length = sum(np.linalg.norm(np.array(p2) - np.array(p1)) for p1, p2 in zip(polyline[:-1], polyline[1:]))
    bounding_box = (min(p[0] for p in polyline), min(p[1] for p in polyline),
                    max(p[0] for p in polyline), max(p[1] for p in polyline))
    is_closed = polyline[0] == polyline[-1]
    return length, bounding_box, is_closed
fig,ax=plt.subplots()
from matplotlib.patches import RegularPolygon
for polyline in polylines:
    length, bounding_box, is_closed = compute_properties(polyline)
    x=[]
    y=[]
    q=np.array([])
    l=[]
    for i in bounding_box:
        
        l.append([i[0],i[1]])
    l.append(l[0])
    xs, ys = zip(*l)
    plt.plot(xs,ys)
    y=np.array(l)
    ax.add_patch(Polygon(y))
    print(bounding_box)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       7     is_closed = polyline[0] == polyline[-1]
#       8     return length, bounding_box, is_closed
# ----> 9 fig,ax=plt.subplots()
#      10 from matplotlib.patches import RegularPolygon
#      11 for polyline in polylines:
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

def compute_properties(polyline):
    length = sum(np.linalg.norm(np.array(p2) - np.array(p1)) for p1, p2 in zip(polyline[:-1], polyline[1:]))
    bounding_box = (min(p[0] for p in polyline), min(p[1] for p in polyline),
                    max(p[0] for p in polyline), max(p[1] for p in polyline))
    is_closed = polyline[0] == polyline[-1]
    return length, bounding_box, is_closed


fig, ax = plt.subplots(1)
ax.set_aspect('equal')

for polyline in polylines:
    length, bounding_box, is_closed = compute_properties(polyline)
    for i in bounding_box:
        x
    min_x, min_y, max_x, max_y = bounding_box
    
    # Create a polygon from the polyline
    poly_patch = Polygon(polyline, closed=is_closed, edgecolor='r', facecolor='none')
    ax.add_patch(poly_patch)
    
    print(f"Length: {length}, Bounding Box: {bounding_box}, Is Closed: {is_closed}")

plt.xlim(-1, 4)
plt.ylim(-1, 4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 21
#      18 min_x, min_y, max_x, max_y = bounding_box
#      20 # Create a polygon from the polyline
# ---> 21 poly_patch = Polygon(polyline, closed=is_closed, edgecolor='r', facecolor='none')
#      22 ax.add_patch(poly_patch)
#      24 print(f"Length: {length}, Bounding Box: {bounding_box}, Is Closed: {is_closed}")
#
# File ~\anaconda3\lib\site-packages\matplotlib\patches.py:1099, in Polygon.__init__(self, xy, closed, **kwargs)
#    1097 super().__init__(**kwargs)
#    1098 self._closed = closed
# -> 1099 self.set_xy(xy)
#
# File ~\anaconda3\lib\site-packages\matplotlib\patches.py:1152, in Polygon.set_xy(self, xy)
#    1136 """
#    1137 Set the vertices of the polygon.
#    1138
#    (...)
#    1149 ``CLOSEPOLY`` vertex, and add it ourselves.
#    1150 """
#    1151 xy = np.asarray(xy)
# ...

# %%
from matplotlib import pyplot as plt
polylines=[x for x in firstimg]
count=0
from PIL import Image
fig=plt.figure(figsize=(10, 6))
for i in polylines:
    plt.plot(i[0][:,0],i[0][:,1])
    count+=1
print(count)
# Convert plot to PIL Image
fig.canvas.draw()
image = Image.frombytes('RGB', fig.canvas.get_width_height(), fig.canvas.tostring_rgb())

# Close the plot to avoid display
plt.close(fig)
import cv2
print(type(image))
image=np.array(image)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
_, threshold = cv2.threshold(gray, 240, 255, cv2.THRESH_BINARY)

# Find contours
contours, _ = cv2.findContours(threshold, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

for contour in contours:
    approx = cv2.approxPolyDP(contour, 0.01 * cv2.arcLength(contour, True), True)
    cv2.drawContours(image, [approx], 0, (0, 255, 0), 5)
import numpy as np
import matplotlib . pyplot as plt
def plot(paths_XYs):
    fig , ax = plt . subplots ( tight_layout = True , figsize =(8 , 8))
    for i , XYs in enumerate ( path_XYs ):
    c = colours [ i % len( colours )]
    for XY in XYs :
        ax.plot( XY [: , 0] , XY [: , 1] , c =c , linewidth =2)
        ax.set_aspect ( ’ equal ’)
    plt . show ()
# Out:
#   Cell In[5], line 36
#     ax.set_aspect ( ’ equal ’)
#                     ^
# SyntaxError: invalid character '’' (U+2019)

# %%
firstimg
# Out:
# [[array([[ 41.94200134,  68.98000336],
#          [ 41.25960541,  69.81170654],
#          [ 40.58875275,  70.65237427],
#          [ 39.92960739,  71.50195312],
#          [ 39.28233719,  72.36040497],
#          [ 38.6471138 ,  73.22766876],
#          [ 38.02410889,  74.10371399],
#          [ 37.4134903 ,  74.98847961],
#          [ 36.81542969,  75.88191986],
#          [ 36.23009109,  76.78398895],
#          [ 35.65765381,  77.69464874],
#          [ 35.09827805,  78.6138382 ],
#          [ 34.55213928,  79.54151917],
#          [ 34.01940155,  80.47764587],
#          [ 33.50024414,  81.42215729],
#          [ 32.99482727,  82.37502289],
#          [ 32.50332642,  83.33618164],
#          [ 32.02590561,  84.30560303],
#          [ 31.56274223,  85.28321838],
#          [ 31.11400032,  86.26899719],
#          [ 30.73366356,  87.13911438],
#          [ 30.36473846,  88.0182724 ],
#          [ 30.00725937,  88.90615845],
#          [ 29.6612606 ,  89.80249023],
# ...

# %%
colours=['red','blue','green','violet','pink','orange','yellow','black',]
import numpy as np
import matplotlib . pyplot as plt
def plot(paths_XYs):
    fig , ax = plt . subplots ( tight_layout = True , figsize =(8 , 8))
    for i , XYs in enumerate(paths_XYs):
        c = colours[ i % len(colours)]
        for XY in XYs :
            ax.plot( XY [: , 0] , XY [: , 1] , c =c , linewidth =2)
            ax.set_aspect ( 'equal')
    plt.show()
plot(firstimg)

# %%
cv2.imshow('Plot Image', image)

# %%
for polyline in polylines:
    plt.plot(polyline[:, 0], polyline[:, 1], marker='o', linestyle='-')polylines=[x for x in firstimg]
# Out:
#   Cell In[12], line 2
#     plt.plot(polyline[:, 0], polyline[:, 1], marker='o', linestyle='-')polylines=[x for x in firstimg]
#                                                                        ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_bezier(t, P0, P1, P2):
    """Calculate a quadratic Bezier curve."""
    return (1 - t)**2 * P0 + 2 * (1 - t) * t * P1 + t**2 * P2

# Control points
P0 = np.array([0, 0])
P1 = np.array([0.5, 1])
P2 = np.array([1, 0])

# Parameter t
t = np.linspace(0, 1, 100)

# Compute the Bezier curve
curve = np.array([quadratic_bezier(i, P0, P1, P2) for i in t])

# Plotting
plt.plot(curve[:, 0], curve[:, 1], label='Quadratic Bezier Curve')
plt.scatter([P0[0], P1[0], P2[0]], [P0[1], P1[1], P2[1]], color='red', label='Control Points')
plt.plot([P0[0], P1[0]], [P0[1], P1[1]], 'r--')
plt.plot([P1[0], P2[0]], [P1[1], P2[1]], 'r--')
plt.title('Quadratic Bezier Curve')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def cubic_bezier(t, P0, P1, P2, P3):
    """Calculate a cubic Bezier curve."""
    return (1 - t)**3 * P0 + 3 * (1 - t)**2 * t * P1 + 3 * (1 - t) * t**2 * P2 + t**3 * P3

# Control points
P0 = np.array([0, 0])
P1 = np.array([0.2, 1])
P2 = np.array([0.8, -1])
P3 = np.array([1, 0])

# Parameter t
t = np.linspace(0, 1, 100)

# Compute the Bezier curve
curve = np.array([cubic_bezier(i, P0, P1, P2, P3) for i in t])

# Plotting
plt.plot(curve[:, 0], curve[:, 1], label='Cubic Bezier Curve')
plt.scatter([P0[0], P1[0], P2[0], P3[0]], [P0[1], P1[1], P2[1], P3[1]], color='red', label='Control Points')
plt.plot([P0[0], P1[0]], [P0[1], P1[1]], 'r--')
plt.plot([P1[0], P2[0]], [P1[1], P2[1]], 'r--')
plt.plot([P2[0], P3[0]], [P2[1], P3[1]], 'r--')
plt.title('Cubic Bezier Curve')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def cubic_bezier(t, P0, P1, P2, P3):
    """Calculate a cubic Bezier curve."""
    return (1 - t)**3 * P0 + 3 * (1 - t)**2 * t * P1 + 3 * (1 - t) * t**2 * P2 + t**3 * P3

def bezier_from_polyline(points):
    """Convert a polyline into a list of cubic Bezier curves."""
    bezier_curves = []
    for i in range(len(points) - 1):
        P0 = points[i]
        P3 = points[i + 1]
        
        if i == 0:
            P1 = P0 + 0.4 * (P3 - P0)
        else:
            P1 = P0 + 0.4 * (P3 - P0)
        
        if i == len(points) - 2:
            P2 = P3 - 0.4 * (P3 - P0)
        else:
            P2 = P3 - 0.4 * (P3 - P0)
        
        bezier_curves.append((P0, P1, P2, P3))
    
    return bezier_curves

# Define a polyline (list of points)


# Convert polyline to cubic Bezier curves

curves = bezier_from_polyline(firstimg[0][0])

# Plotting
t = np.linspace(0, 1, 100)
plt.figure()
for curve in curves:
    P0, P1, P2, P3 = curve
    bezier_curve = np.array([cubic_bezier(i, P0, P1, P2, P3) for i in t])
    plt.plot(bezier_curve[:, 0], bezier_curve[:, 1], 'b-')
    plt.scatter([P0[0], P1[0], P2[0], P3[0]], [P0[1], P1[1], P2[1], P3[1]], color='red')

plt.title('Cubic Bezier Approximation of Polyline')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %%
print(type(firstimg[0][0]))
# Out:
# <class 'numpy.ndarray'>

# %%
fig=plt.figure()
for i in firstimg:
    curves = bezier_from_polyline(i[0])
    for curve in curves:
        P0, P1, P2, P3 = curve
        bezier_curve = np.array([cubic_bezier(i, P0, P1, P2, P3) for i in t])
        plt.plot(bezier_curve[:, 0], bezier_curve[:, 1], 'b-')
        plt.scatter([P0[0], P1[0], P2[0], P3[0]], [P0[1], P1[1], P2[1], P3[1]], color='red')

plt.title('Cubic Bezier Approximation of Polyline')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
fig.savefig(r'C:\Users\ACER\Downloads\curve1.png',bbox_inches='tight',pad_inches=0)

# %%
import cv2
img=cv2.imread(r'C:\Users\ACER\Downloads\curve1.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
  
# setting threshold of gray image 
_, threshold = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY) 
  
# using a findContours() function 
contours, _ = cv2.findContours( 
    threshold, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE) 
i = 0
  
# list for storing names of shapes 
for contour in contours: 
  
    # here we are ignoring first counter because  
    # findcontour function detects whole image as shape 
    if i == 0: 
        i = 1
        continue
  
    # cv2.approxPloyDP() function to approximate the shape 
    approx = cv2.approxPolyDP( 
        contour, 0.01 * cv2.arcLength(contour, True), True) 
      
    # using drawContours() function 
    cv2.drawContours(img, [contour], 0, (0, 0, 255), 5) 
  
    # finding center point of shape 
    M = cv2.moments(contour) 
    if M['m00'] != 0.0: 
        x = int(M['m10']/M['m00']) 
        y = int(M['m01']/M['m00']) 
  
    # putting shape name at center of each shape 
    if len(approx) == 3: 
        cv2.putText(img, 'Triangle', (x, y), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2) 
  
    elif len(approx) == 4: 
        print('rectangle')
        cv2.putText(img, 'Quadrilateral', (x, y), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2) 
  
    elif len(approx) == 5: 
        cv2.putText(img, 'Pentagon', (x, y), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2) 
  
    elif len(approx) == 6: 
        cv2.putText(img, 'Hexagon', (x, y), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2) 
  
    else: 
        print('Circle')
        cv2.putText(img, 'circle', (x, y), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.1, (255, 255, 255), 2) 
  
cv2.imshow('shapes', img) 
  
cv2.waitKey(0) 
cv2.destroyAllWindows()
# Out:
# rectangle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# rectangle
# rectangle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# rectangle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# rectangle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle
# Circle

# %%
q=np.linspace(1,2,100)
print(q)
# Out:
# [1.         1.01010101 1.02020202 1.03030303 1.04040404 1.05050505
#  1.06060606 1.07070707 1.08080808 1.09090909 1.1010101  1.11111111
#  1.12121212 1.13131313 1.14141414 1.15151515 1.16161616 1.17171717
#  1.18181818 1.19191919 1.2020202  1.21212121 1.22222222 1.23232323
#  1.24242424 1.25252525 1.26262626 1.27272727 1.28282828 1.29292929
#  1.3030303  1.31313131 1.32323232 1.33333333 1.34343434 1.35353535
#  1.36363636 1.37373737 1.38383838 1.39393939 1.4040404  1.41414141
#  1.42424242 1.43434343 1.44444444 1.45454545 1.46464646 1.47474747
#  1.48484848 1.49494949 1.50505051 1.51515152 1.52525253 1.53535354
#  1.54545455 1.55555556 1.56565657 1.57575758 1.58585859 1.5959596
#  1.60606061 1.61616162 1.62626263 1.63636364 1.64646465 1.65656566
#  1.66666667 1.67676768 1.68686869 1.6969697  1.70707071 1.71717172
#  1.72727273 1.73737374 1.74747475 1.75757576 1.76767677 1.77777778
#  1.78787879 1.7979798  1.80808081 1.81818182 1.82828283 1.83838384
# ...

# %%
polylines
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 polylines
#
# NameError: name 'polylines' is not defined

# %%
import cv2
import numpy as np

# Create a black image with white dots
image = np.zeros((100, 100), dtype=np.uint8)
image[20, 30] = 255
image[40, 50] = 255

# Detect edges in the image
edges = cv2.Canny(image, 50, 150)

# Apply the Hough Transform to find lines
lines = cv2.HoughLines(edges, 1, np.pi / 180, 10)

# Draw the lines on the image
output = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
for line in lines:
    rho, theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a * rho
    y0 = b * rho
    x1 = int(x0 + 1000 * (-b))
    y1 = int(y0 + 1000 * (a))
    x2 = int(x0 - 1000 * (-b))
    y2 = int(y0 - 1000 * (a))
    cv2.line(output, (x1, y1), (x2, y2), (0, 0, 255), 2)

# Display the image
cv2.imshow('Hough Transform', output)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 17
#      15 # Draw the lines on the image
#      16 output = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
# ---> 17 for line in lines:
#      18     rho, theta = line[0]
#      19     a = np.cos(theta)
#
# TypeError: 'NoneType' object is not iterable

# %%
from ultralytics import YOLO

# Load the trained model
model = YOLO("../content/runs/segment/train3/weights/best.pt")
import cv2
# Load the image
img = cv2.imread("../content/drive/MyDrive/adobe_projectforgenai/curve1.png")

# Make predictions on the image
results = model(img)
print(results)

# Iterate over the results
for result in results:
    boxes = result.boxes.xyxy.cpu().numpy()  # Bounding boxes
    scores = result.boxes.conf.cpu().numpy()  # Confidence scores
    classes = result.boxes.cls.cpu().numpy().astype(int)  # Class IDs

    # Iterate over the detections
    for box, score, cls in zip(boxes, scores, classes):
        x1, y1, x2, y2 = [int(c) for c in box]
        class_name = model.names[cls]
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(img, f"{class_name} {score:.2f}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (36, 255, 12), 2)

# Display the image with predictions
cv2.imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 4
#       1 from ultralytics import YOLO
#       3 # Load the trained model
# ----> 4 model = YOLO("../content/runs/segment/train3/weights/best.pt")
#       5 import cv2
#       6 # Load the image
#
# File ~\anaconda3\lib\site-packages\ultralytics\engine\model.py:94, in Model.__init__(self, model, task)
#      92     self._new(model, task)
#      93 else:
# ---> 94     self._load(model, task)
#
# File ~\anaconda3\lib\site-packages\ultralytics\engine\model.py:146, in Model._load(self, weights, task)
#     144 suffix = Path(weights).suffix
#     145 if suffix == '.pt':
# --> 146     self.model, self.ckpt = attempt_load_one_weight(weights)
#     147     self.task = self.model.args['task']
#     148     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# ...

# %%
import numpy as np
import cv2 as cv
img=cv.imread(r'C:\Users\ACER\Downloads\curve1.png',cv.IMREAD_GRAYSCALE)
plt.imshow(img)
blurred_image = cv.GaussianBlur(img, (9, 9), 2)
print(img.shape)

circles = cv.HoughCircles(blurred_image,cv.HOUGH_GRADIENT,1,200000000,
                            param1=300,param2=0.9,minRadius=100,maxRadius=200)
circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    print(i[0])
    cv.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv.circle(cimg,(i[0],i[1]),2,(0,0,255),3)
    
cv.imshow('detected circles',cimg)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# (435, 551)
# 278

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# Load the image in grayscale
img = cv.imread(r'C:\Users\ACER\Downloads\curve1.png', cv.IMREAD_GRAYSCALE)

# Check if the image is loaded correctly
if img is None:
    raise ValueError("Image not loaded. Check the file path.")

# Display the grayscale image
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.show()

# Apply Gaussian blur to reduce noise
blurred_image = cv.GaussianBlur(img, (9, 9), 2)

# Apply Hough Circle Transform
circles = cv.HoughCircles(
    blurred_image,
    cv.HOUGH_GRADIENT,
    dp=1,
    minDist=50,     # Set a reasonable minimum distance between circles
    param1=100,     # Change to improve edge detection
    param2=10,      # Change to fine-tune circle center detection
    minRadius=119,   # Minimum radius of detected circles
    maxRadius=120   # Maximum radius of detected circles
)

# Check if any circles are detected
if circles is not None:
    circles = np.uint16(np.around(circles))

    # Create a copy of the image to draw circles on
    cimg = cv.cvtColor(img, cv.COLOR_GRAY2BGR)

    for i in circles[0, :]:
        # Draw the outer circle
        cv.circle(cimg, (i[0], i[1]), i[2], (0, 255, 0), 2)
        # Draw the center of the circle
        cv.circle(cimg, (i[0], i[1]), 2, (0, 0, 255), 3)

    # Display the image with detected circles
    cv.imshow('Detected Circles', cimg)
    print(cimg.shape)
else:
    print("No circles were detected.")

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# (435, 551, 3)

# %%
# !pip uninstall ultralytics
# !pip install ultralytics

# %%
from ultralytics import YOLO
# Load the trained model
model = YOLO(r"C:\Users\ACER\Downloads\best (4)final.pt")
import cv2
# Load the image
img = cv2.imread(r"C:\Users\ACER\Downloads\curve1.png")

# Make predictions on the image
results = model(img)
print(results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 9
#       6 img = cv2.imread(r"C:\Users\ACER\Downloads\curve1.png")
#       8 # Make predictions on the image
# ----> 9 results = model(img)
#      10 print(results)
#
# File ~\anaconda3\lib\site-packages\ultralytics\engine\model.py:98, in Model.__call__(self, source, stream, **kwargs)
#      96 def __call__(self, source=None, stream=False, **kwargs):
#      97     """Calls the predict() method with given arguments to perform object detection."""
# ---> 98     return self.predict(source, stream, **kwargs)
#
# File ~\anaconda3\lib\site-packages\ultralytics\engine\model.py:257, in Model.predict(self, source, stream, predictor, **kwargs)
#     255 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     256     self.predictor.set_prompts(prompts)
# ...

# %%
def detect_circles(image, min_radius=10, max_radius=100):
    # Apply some blur to reduce noise
    blurred = cv2.GaussianBlur(image, (5, 5), 0)
    
    circles = cv2.HoughCircles(blurred, cv2.HOUGH_GRADIENT, 1, 20,
                               param1=50, param2=30,
                               minRadius=min_radius, maxRadius=max_radius)
    
    if circles is not None:
        circles = np.round(circles[0, :]).astype("int")
    
    return circles

def estimate_radius_range(image):
    height, width = image.shape[:2]
    max_dimension = max(width, height)
    
    max_radius = int(max_dimension * 0.5)  # Adjust this factor as needed
    min_radius = int(max_dimension * 0.02)  # Adjust this factor as needed
    
    return min_radius, max_radius

min_r, max_r = estimate_radius_range(blurred_image)
detected_circles = detect_circles(blurred_image, min_r, max_r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 24
#      21     return min_radius, max_radius
#      23 min_r, max_r = estimate_radius_range(blurred_image)
# ---> 24 detected_circles = detect_circles(blurred_image, min_r, max_r)
#
# Cell In[20], line 3, in detect_circles(image, min_radius, max_radius)
#       1 def detect_circles(image, min_radius=10, max_radius=100):
#       2     # Apply some blur to reduce noise
# ----> 3     blurred = cv2.GaussianBlur(image, (5, 5), 0)
#       5     circles = cv2.HoughCircles(blurred, cv2.HOUGH_GRADIENT, 1, 20,
#       6                                param1=50, param2=30,
#       7                                minRadius=min_radius, maxRadius=max_radius)
#       9     if circles is not None:
#
# NameError: name 'cv2' is not defined

# %%
def draw_circles(image, circles):
    output = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
    if circles is not None:
        for (x, y, r) in circles:
            cv2.circle(output, (x, y), r, (0, 255, 0), 2)
            cv2.circle(output, (x, y), 2, (0, 0, 255), 3)
    return output

result_image = draw_circles(blurred_image, detected_circles)
cv2.imshow("Detected Circles", result_image)
cv2.waitKey(0)

# %%
import cv2
